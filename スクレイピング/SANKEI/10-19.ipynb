# %%
from bs4 import BeautifulSoup
import requests
import time

def sankei_news_scraping(topic):
    url = 'https://www.sankei.com/'
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")
    elements = soup.select('.nav-link')
    categories_elements = elements[11:18]
    
    #カテゴリーのURL取得
    category_urls = []
    for i, element in enumerate(categories_elements):
        link = 'https://www.sankei.com/' + element.a['href']
        category_urls.append(link)

        if (topic == element.text):
            categories_num = i
        time.sleep(0.2)
    
    r = requests.get(category_urls[categories_num])
    soup = BeautifulSoup(r.text, "html.parser")
    elements = soup.select('.ranking__item ')
    
    #取得するニュースの数を５つにしている
    elements = elements[0:5]
    
    #ニュースのURLの取得
    news_urls = []
    for element in elements:
        link = element.a['href']
        news_urls.append(link)
        time.sleep(0.2)
    
    #ニュースの本文を取得
    news_text = []
    for news_url in news_urls:
        r = requests.get(news_url)
        soup = BeautifulSoup(r.text, "html.parser")
        elements = soup.select('.article-text')

        time.sleep(0.2)
    
        text = ''
        for element in elements:
            text += element.text
            
        news_text.append(text)

    articles = []
    for url, text in zip(news_urls, news_text):
        article = {
            "URL" : url,
            "text" : text
        }
        articles.append(article)

    return articles

# %%
a = sankei_news_scraping('スポーツ')

# %%
a
# Out:
# [{'URL': 'https://www.sankei.com/article/20231207-6OYXZBWDCZDGFMZIGQBHW3IAKA/',
#   'text': '１２月４日に開幕した米大リーグ（ＭＬＢ）の「ウインターミーティング」で話題の中心となっているのが、エンゼルスから今季フリーエージェント（ＦＡ）となった大谷翔平選手（２９）。ただ、面談した有無などについても詳細が明かされないベールに包まれた交渉過程に、一部の米メディアからは「この秘密に一体何の意味があるのか」といった批判も起きている。複数球団による争奪戦の様相を呈す中、一部メディアがエンゼルスとの再契約の可能性について言及するなど、最終局面を迎えた大谷の交渉を巡って米メディアの報道が過熱している。米・テネシー州ナッシュビルで７日（日本時間８日）まで行われるウインターミーティングは、ゼネラルマネジャー（ＧＭ）など球団幹部や代理人らが一堂に会し、移籍交渉などを行う１２月の恒例行事。今年のウインターミーティングで話題の中心となっているのは、ほかでもない大谷だ。だが、大谷の移籍交渉に関しては球団幹部も一様に口が堅く、進展しているかどうかも含めて不透明な状況。一方で、獲得に名乗りを上げているドジャースのロバーツ監督が大谷との面談を認めた発言が米メディアで大きく取り上げられるなど、異様な展開となっている。米スポーツ専門局のＥＳＰＮ（電子版）は「この〝秘密〟には一体何の意味があるのか」と疑問を呈し、「大谷はこれまでのどの選手よりも大きな影響力を持っており、誰もが彼を欲しがっている。その代わり、彼の決定はスパイ交換を巡る交渉のように扱われている」として、注目度の高さに反してベールに包まれた交渉過程に皮肉を込めた。最終局面を迎えているとみられる大谷の移籍交渉を巡っては、ドジャースやブルージェイズ、ジャイアンツといったチームの名前が挙がる一方、エンゼルスとの再契約の可能性について言及するメディアも出ている。ＭＬＢの公式サイトは、「大谷を巡るＦＡの過程は謎に包まれている」と前置きした上で、「エンゼルスが大谷に提供できる最大の利点は安心感。ウインターミーティングに参加する関係者の多くが、最終的には大谷がエンゼルスと再契約すると信じていると述べたのは、このことが理由だ」と指摘した。その一方で、「大谷はＦＡ（の交渉過程）を可能な限り非公開にしたいと考えており、他球団との面談に関する話が彼の決断に影響を与えるかどうかは不明だ」との見方を示した。大リーグ評論家の福島良一さんは「今回のＦＡは大谷選手にとっても重要な契約。どの球団が自分にとってベストなのか、自分の目で確かめた上で判断したいのでは」と話している。'},
